# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
import tensorflow as tf
print(tf.__version__)

import os
# from google.colab import drive 
# drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd 'gdrive/My Drive'
# os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4 # 可以自己改路徑
# Out:
# 1.14.0

# %%
if not os.path.exists("training.csv"):
  print("training.zip doesn't exist, downloading...")
  os.system("wget https://cvdl-fileentity.cupoy.com/2nd/homework/example/1580979702425/training.zip")
  print("unzip training.zip...")
  os.system("unzip training.zip")
else:
  print("training.csv exist")

if not os.path.exists("test.csv"):
  print("test.zip doesn't exist, downloading...")
  os.system("wget https://cvdl-fileentity.cupoy.com/2nd/homework/example/1580979702425/test.zip")
  print("unzip test.zip...")
  os.system("unzip test.zip")
else:
  print("test.csv exist")
# Out:
# training.zip doesn't exist, downloading...
# unzip training.zip...
# test.zip doesn't exist, downloading...
# unzip test.zip...

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
# input shape 是 96x96
# output shape 是一個 30 維的向量
imgs_train, points_train = load_data(dirname = 'training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0409 17:18:46.281721 140523076396864 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0409 17:18:46.291527 140523076396864 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0409 17:18:46.293307 140523076396864 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0409 17:18:46.304767 140523076396864 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0409 17:18:46.347712 140523076396864 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# W0409 17:18:46.352966 140523076396864 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0409 17:18:46.389889 140523076396864 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# 印出網路結構
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# W0409 17:19:27.215372 140523076396864 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
# Train on 1712 samples, validate on 428 samples
# Epoch 1/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 0.0065 - val_loss: 0.0020
#
# Epoch 00001: val_loss improved from inf to 0.00203, saving model to best_weights.h5
# Epoch 2/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 0.0016 - val_loss: 0.0023
#
# Epoch 00002: val_loss did not improve from 0.00203
# Epoch 3/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 0.0013 - val_loss: 0.0019
#
# Epoch 00003: val_loss improved from 0.00203 to 0.00191, saving model to best_weights.h5
# Epoch 4/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 0.0012 - val_loss: 0.0018
#
# Epoch 00004: val_loss improved from 0.00191 to 0.00183, saving model to best_weights.h5
# Epoch 5/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 0.0011 - val_loss: 0.0019
#
# Epoch 00005: val_loss did not improve from 0.00183
# Epoch 6/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 9.8979e-04 - val_loss: 0.0018
#
# Epoch 00006: val_loss improved from 0.00183 to 0.00177, saving model to best_weights.h5
# Epoch 7/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 8.9744e-04 - val_loss: 0.0017
#
# Epoch 00007: val_loss improved from 0.00177 to 0.00165, saving model to best_weights.h5
# Epoch 8/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 7.7177e-04 - val_loss: 0.0015
#
# Epoch 00008: val_loss improved from 0.00165 to 0.00154, saving model to best_weights.h5
# Epoch 9/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 7.0491e-04 - val_loss: 0.0014
#
# Epoch 00009: val_loss improved from 0.00154 to 0.00138, saving model to best_weights.h5
# Epoch 10/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 6.1802e-04 - val_loss: 0.0012
#
# Epoch 00010: val_loss improved from 0.00138 to 0.00122, saving model to best_weights.h5
# Epoch 11/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 5.5831e-04 - val_loss: 0.0012
#
# Epoch 00011: val_loss did not improve from 0.00122
# Epoch 12/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 5.1284e-04 - val_loss: 0.0012
#
# Epoch 00012: val_loss improved from 0.00122 to 0.00116, saving model to best_weights.h5
# Epoch 13/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 4.7133e-04 - val_loss: 0.0011
#
# Epoch 00013: val_loss improved from 0.00116 to 0.00114, saving model to best_weights.h5
# Epoch 14/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 4.4454e-04 - val_loss: 0.0010
#
# Epoch 00014: val_loss improved from 0.00114 to 0.00101, saving model to best_weights.h5
# Epoch 15/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 4.1564e-04 - val_loss: 9.6467e-04
#
# Epoch 00015: val_loss improved from 0.00101 to 0.00096, saving model to best_weights.h5
# Epoch 16/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 4.0409e-04 - val_loss: 9.7838e-04
#
# Epoch 00016: val_loss did not improve from 0.00096
# Epoch 17/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 3.9236e-04 - val_loss: 9.3817e-04
#
# Epoch 00017: val_loss improved from 0.00096 to 0.00094, saving model to best_weights.h5
# Epoch 18/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 3.6489e-04 - val_loss: 8.8588e-04
#
# Epoch 00018: val_loss improved from 0.00094 to 0.00089, saving model to best_weights.h5
# Epoch 19/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 3.4496e-04 - val_loss: 8.8264e-04
#
# Epoch 00019: val_loss improved from 0.00089 to 0.00088, saving model to best_weights.h5
# Epoch 20/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 3.3463e-04 - val_loss: 8.4629e-04
#
# Epoch 00020: val_loss improved from 0.00088 to 0.00085, saving model to best_weights.h5
# Epoch 21/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 3.1960e-04 - val_loss: 8.5152e-04
#
# Epoch 00021: val_loss did not improve from 0.00085
# Epoch 22/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 3.1325e-04 - val_loss: 8.2894e-04
#
# Epoch 00022: val_loss improved from 0.00085 to 0.00083, saving model to best_weights.h5
# Epoch 23/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 3.0340e-04 - val_loss: 8.3796e-04
#
# Epoch 00023: val_loss did not improve from 0.00083
# Epoch 24/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 2.9059e-04 - val_loss: 8.0510e-04
#
# Epoch 00024: val_loss improved from 0.00083 to 0.00081, saving model to best_weights.h5
# Epoch 25/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 2.8862e-04 - val_loss: 8.4603e-04
#
# Epoch 00025: val_loss did not improve from 0.00081
# Epoch 26/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 2.8104e-04 - val_loss: 7.7798e-04
#
# Epoch 00026: val_loss improved from 0.00081 to 0.00078, saving model to best_weights.h5
# Epoch 27/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 2.7071e-04 - val_loss: 8.0566e-04
#
# Epoch 00027: val_loss did not improve from 0.00078
# Epoch 28/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 2.6580e-04 - val_loss: 7.9830e-04
#
# Epoch 00028: val_loss did not improve from 0.00078
# Epoch 29/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 2.6213e-04 - val_loss: 7.7780e-04
#
# Epoch 00029: val_loss improved from 0.00078 to 0.00078, saving model to best_weights.h5
# Epoch 30/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 2.6671e-04 - val_loss: 7.7608e-04
#
# Epoch 00030: val_loss improved from 0.00078 to 0.00078, saving model to best_weights.h5
# Epoch 31/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 2.4923e-04 - val_loss: 7.8495e-04
#
# Epoch 00031: val_loss did not improve from 0.00078
# Epoch 32/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 2.4067e-04 - val_loss: 7.7746e-04
#
# Epoch 00032: val_loss did not improve from 0.00078
# Epoch 33/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 2.3878e-04 - val_loss: 7.4747e-04
#
# Epoch 00033: val_loss improved from 0.00078 to 0.00075, saving model to best_weights.h5
# Epoch 34/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 2.4329e-04 - val_loss: 7.6185e-04
#
# Epoch 00034: val_loss did not improve from 0.00075
# Epoch 35/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 2.3627e-04 - val_loss: 7.5006e-04
#
# Epoch 00035: val_loss did not improve from 0.00075
# Epoch 36/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 2.3217e-04 - val_loss: 7.4908e-04
#
# Epoch 00036: val_loss did not improve from 0.00075
# Epoch 37/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 2.2730e-04 - val_loss: 8.3681e-04
#
# Epoch 00037: val_loss did not improve from 0.00075
# Epoch 38/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 2.2442e-04 - val_loss: 7.4796e-04
#
# Epoch 00038: val_loss did not improve from 0.00075
# Epoch 39/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 2.2456e-04 - val_loss: 7.5100e-04
#
# Epoch 00039: val_loss did not improve from 0.00075
# Epoch 40/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 2.1916e-04 - val_loss: 7.3815e-04
#
# Epoch 00040: val_loss improved from 0.00075 to 0.00074, saving model to best_weights.h5
# Epoch 41/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 2.1499e-04 - val_loss: 7.2492e-04
#
# Epoch 00041: val_loss improved from 0.00074 to 0.00072, saving model to best_weights.h5
# Epoch 42/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 2.0602e-04 - val_loss: 7.7127e-04
#
# Epoch 00042: val_loss did not improve from 0.00072
# Epoch 43/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 2.0571e-04 - val_loss: 7.5713e-04
#
# Epoch 00043: val_loss did not improve from 0.00072
# Epoch 44/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 2.0554e-04 - val_loss: 7.3360e-04
#
# Epoch 00044: val_loss did not improve from 0.00072
# Epoch 45/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 2.0046e-04 - val_loss: 7.4883e-04
#
# Epoch 00045: val_loss did not improve from 0.00072
# Epoch 46/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.9932e-04 - val_loss: 7.2646e-04
#
# Epoch 00046: val_loss did not improve from 0.00072
# Epoch 47/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.9309e-04 - val_loss: 7.3344e-04
#
# Epoch 00047: val_loss did not improve from 0.00072
# Epoch 48/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.9151e-04 - val_loss: 7.2949e-04
#
# Epoch 00048: val_loss did not improve from 0.00072
# Epoch 49/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.8480e-04 - val_loss: 7.3932e-04
#
# Epoch 00049: val_loss did not improve from 0.00072
# Epoch 50/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.8420e-04 - val_loss: 7.6393e-04
#
# Epoch 00050: val_loss did not improve from 0.00072
# Epoch 51/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.8173e-04 - val_loss: 7.2676e-04
#
# Epoch 00051: val_loss did not improve from 0.00072
# Epoch 52/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.8417e-04 - val_loss: 7.4541e-04
#
# Epoch 00052: val_loss did not improve from 0.00072
# Epoch 53/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.8210e-04 - val_loss: 7.4946e-04
#
# Epoch 00053: val_loss did not improve from 0.00072
# Epoch 54/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.7312e-04 - val_loss: 7.2964e-04
#
# Epoch 00054: val_loss did not improve from 0.00072
# Epoch 55/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.8288e-04 - val_loss: 7.8315e-04
#
# Epoch 00055: val_loss did not improve from 0.00072
# Epoch 56/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.7266e-04 - val_loss: 7.3221e-04
#
# Epoch 00056: val_loss did not improve from 0.00072
# Epoch 57/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.6933e-04 - val_loss: 7.8787e-04
#
# Epoch 00057: val_loss did not improve from 0.00072
# Epoch 58/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.6770e-04 - val_loss: 7.1736e-04
#
# Epoch 00058: val_loss improved from 0.00072 to 0.00072, saving model to best_weights.h5
# Epoch 59/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.6304e-04 - val_loss: 7.5616e-04
#
# Epoch 00059: val_loss did not improve from 0.00072
# Epoch 60/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.6255e-04 - val_loss: 7.5199e-04
#
# Epoch 00060: val_loss did not improve from 0.00072
# Epoch 61/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.6318e-04 - val_loss: 7.4154e-04
#
# Epoch 00061: val_loss did not improve from 0.00072
# Epoch 62/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.6812e-04 - val_loss: 7.2672e-04
#
# Epoch 00062: val_loss did not improve from 0.00072
# Epoch 63/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.5852e-04 - val_loss: 7.3780e-04
#
# Epoch 00063: val_loss did not improve from 0.00072
# Epoch 64/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.6246e-04 - val_loss: 8.1137e-04
#
# Epoch 00064: val_loss did not improve from 0.00072
# Epoch 65/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.6063e-04 - val_loss: 7.7764e-04
#
# Epoch 00065: val_loss did not improve from 0.00072
# Epoch 66/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.5783e-04 - val_loss: 7.0195e-04
#
# Epoch 00066: val_loss improved from 0.00072 to 0.00070, saving model to best_weights.h5
# Epoch 67/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.5598e-04 - val_loss: 7.3942e-04
#
# Epoch 00067: val_loss did not improve from 0.00070
# Epoch 68/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.5250e-04 - val_loss: 7.4559e-04
#
# Epoch 00068: val_loss did not improve from 0.00070
# Epoch 69/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.5281e-04 - val_loss: 7.1755e-04
#
# Epoch 00069: val_loss did not improve from 0.00070
# Epoch 70/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.5266e-04 - val_loss: 7.1622e-04
#
# Epoch 00070: val_loss did not improve from 0.00070
# Epoch 71/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.4911e-04 - val_loss: 7.4451e-04
#
# Epoch 00071: val_loss did not improve from 0.00070
# Epoch 72/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.5518e-04 - val_loss: 7.6806e-04
#
# Epoch 00072: val_loss did not improve from 0.00070
# Epoch 73/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.4643e-04 - val_loss: 7.4283e-04
#
# Epoch 00073: val_loss did not improve from 0.00070
# Epoch 74/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.4833e-04 - val_loss: 7.1599e-04
#
# Epoch 00074: val_loss did not improve from 0.00070
# Epoch 75/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.4757e-04 - val_loss: 7.5562e-04
#
# Epoch 00075: val_loss did not improve from 0.00070
# Epoch 76/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.4078e-04 - val_loss: 7.0260e-04
#
# Epoch 00076: val_loss did not improve from 0.00070
# Epoch 77/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.3867e-04 - val_loss: 7.4477e-04
#
# Epoch 00077: val_loss did not improve from 0.00070
# Epoch 78/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.4391e-04 - val_loss: 7.3115e-04
#
# Epoch 00078: val_loss did not improve from 0.00070
# Epoch 79/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.4118e-04 - val_loss: 7.5379e-04
#
# Epoch 00079: val_loss did not improve from 0.00070
# Epoch 80/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.3956e-04 - val_loss: 7.7839e-04
#
# Epoch 00080: val_loss did not improve from 0.00070
# Epoch 81/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.3968e-04 - val_loss: 7.2875e-04
#
# Epoch 00081: val_loss did not improve from 0.00070
# Epoch 82/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.3957e-04 - val_loss: 7.4280e-04
#
# Epoch 00082: val_loss did not improve from 0.00070
# Epoch 83/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.3453e-04 - val_loss: 7.1068e-04
#
# Epoch 00083: val_loss did not improve from 0.00070
# Epoch 84/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.3727e-04 - val_loss: 7.5734e-04
#
# Epoch 00084: val_loss did not improve from 0.00070
# Epoch 85/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.3372e-04 - val_loss: 7.4091e-04
#
# Epoch 00085: val_loss did not improve from 0.00070
# Epoch 86/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.3059e-04 - val_loss: 7.4660e-04
#
# Epoch 00086: val_loss did not improve from 0.00070
# Epoch 87/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.3210e-04 - val_loss: 7.4761e-04
#
# Epoch 00087: val_loss did not improve from 0.00070
# Epoch 88/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.3246e-04 - val_loss: 7.5527e-04
#
# Epoch 00088: val_loss did not improve from 0.00070
# Epoch 89/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.3189e-04 - val_loss: 7.6162e-04
#
# Epoch 00089: val_loss did not improve from 0.00070
# Epoch 90/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.2913e-04 - val_loss: 7.6480e-04
#
# Epoch 00090: val_loss did not improve from 0.00070
# Epoch 91/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.2540e-04 - val_loss: 7.8040e-04
#
# Epoch 00091: val_loss did not improve from 0.00070
# Epoch 92/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.2857e-04 - val_loss: 7.3786e-04
#
# Epoch 00092: val_loss did not improve from 0.00070
# Epoch 93/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.2512e-04 - val_loss: 7.4251e-04
#
# Epoch 00093: val_loss did not improve from 0.00070
# Epoch 94/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.2534e-04 - val_loss: 7.3771e-04
#
# Epoch 00094: val_loss did not improve from 0.00070
# Epoch 95/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.2511e-04 - val_loss: 7.5541e-04
# Epoch 00095: val_loss did not improve from 0.00070
# Epoch 96/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.2096e-04 - val_loss: 7.0582e-04
#
# Epoch 00096: val_loss did not improve from 0.00070
# Epoch 97/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.2116e-04 - val_loss: 7.1157e-04
#
# Epoch 00097: val_loss did not improve from 0.00070
# Epoch 98/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.1954e-04 - val_loss: 7.4325e-04
#
# Epoch 00098: val_loss did not improve from 0.00070
# Epoch 99/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.1749e-04 - val_loss: 7.3442e-04
#
# Epoch 00099: val_loss did not improve from 0.00070
# Epoch 100/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.1679e-04 - val_loss: 7.2622e-04
#
# Epoch 00100: val_loss did not improve from 0.00070
# Epoch 101/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.1638e-04 - val_loss: 7.4342e-04
#
# Epoch 00101: val_loss did not improve from 0.00070
# Epoch 102/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.1521e-04 - val_loss: 7.2397e-04
#
# Epoch 00102: val_loss did not improve from 0.00070
# Epoch 103/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.1484e-04 - val_loss: 7.4323e-04
#
# Epoch 00103: val_loss did not improve from 0.00070
# Epoch 104/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.1822e-04 - val_loss: 7.2386e-04
#
# Epoch 00104: val_loss did not improve from 0.00070
# Epoch 105/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.1847e-04 - val_loss: 7.6703e-04
#
# Epoch 00105: val_loss did not improve from 0.00070
# Epoch 106/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.1711e-04 - val_loss: 7.5171e-04
#
# Epoch 00106: val_loss did not improve from 0.00070
# Epoch 107/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.1212e-04 - val_loss: 7.1486e-04
#
# Epoch 00107: val_loss did not improve from 0.00070
# Epoch 108/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.1042e-04 - val_loss: 7.6112e-04
#
# Epoch 00108: val_loss did not improve from 0.00070
# Epoch 109/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.1207e-04 - val_loss: 7.4989e-04
#
# Epoch 00109: val_loss did not improve from 0.00070
# Epoch 110/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.1142e-04 - val_loss: 7.4529e-04
#
# Epoch 00110: val_loss did not improve from 0.00070
# Epoch 111/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.0620e-04 - val_loss: 7.1525e-04
#
# Epoch 00111: val_loss did not improve from 0.00070
# Epoch 112/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.0736e-04 - val_loss: 7.5092e-04
#
# Epoch 00112: val_loss did not improve from 0.00070
# Epoch 113/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.0848e-04 - val_loss: 7.3291e-04
#
# Epoch 00113: val_loss did not improve from 0.00070
# Epoch 114/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.0543e-04 - val_loss: 7.2254e-04
#
# Epoch 00114: val_loss did not improve from 0.00070
# Epoch 115/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.0806e-04 - val_loss: 7.0890e-04
#
# Epoch 00115: val_loss did not improve from 0.00070
# Epoch 116/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.0517e-04 - val_loss: 7.3323e-04
#
# Epoch 00116: val_loss did not improve from 0.00070
# Epoch 117/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.0645e-04 - val_loss: 7.4470e-04
#
# Epoch 00117: val_loss did not improve from 0.00070
# Epoch 118/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.0139e-04 - val_loss: 7.5868e-04
#
# Epoch 00118: val_loss did not improve from 0.00070
# Epoch 119/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.0259e-04 - val_loss: 7.3307e-04
#
# Epoch 00119: val_loss did not improve from 0.00070
# Epoch 120/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 9.9816e-05 - val_loss: 7.2861e-04
#
# Epoch 00120: val_loss did not improve from 0.00070
# Epoch 121/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.0072e-04 - val_loss: 7.1082e-04
#
# Epoch 00121: val_loss did not improve from 0.00070
# Epoch 122/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.0085e-04 - val_loss: 7.4895e-04
#
# Epoch 00122: val_loss did not improve from 0.00070
# Epoch 123/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 9.9170e-05 - val_loss: 7.4036e-04
#
# Epoch 00123: val_loss did not improve from 0.00070
# Epoch 124/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.0329e-04 - val_loss: 7.0799e-04
#
# Epoch 00124: val_loss did not improve from 0.00070
# Epoch 125/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.0303e-04 - val_loss: 7.4500e-04
#
# Epoch 00125: val_loss did not improve from 0.00070
# Epoch 126/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 1.0208e-04 - val_loss: 7.3869e-04
#
# Epoch 00126: val_loss did not improve from 0.00070
# Epoch 127/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 9.5418e-05 - val_loss: 7.3508e-04
#
# Epoch 00127: val_loss did not improve from 0.00070
# Epoch 128/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 9.7413e-05 - val_loss: 7.2644e-04
#
# Epoch 00128: val_loss did not improve from 0.00070
# Epoch 129/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 9.7235e-05 - val_loss: 7.3078e-04
#
# Epoch 00129: val_loss did not improve from 0.00070
# Epoch 130/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 9.4799e-05 - val_loss: 7.2050e-04
#
# Epoch 00130: val_loss did not improve from 0.00070
# Epoch 131/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 9.4123e-05 - val_loss: 7.1962e-04
#
# Epoch 00131: val_loss did not improve from 0.00070
# Epoch 132/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 9.5228e-05 - val_loss: 7.3428e-04
#
# Epoch 00132: val_loss did not improve from 0.00070
# Epoch 133/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 9.4452e-05 - val_loss: 7.5134e-04
#
# Epoch 00133: val_loss did not improve from 0.00070
# Epoch 134/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 9.3327e-05 - val_loss: 7.5957e-04
#
# Epoch 00134: val_loss did not improve from 0.00070
# Epoch 135/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 9.5511e-05 - val_loss: 7.4070e-04
#
# Epoch 00135: val_loss did not improve from 0.00070
# Epoch 136/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 9.3869e-05 - val_loss: 7.3846e-04
#
# Epoch 00136: val_loss did not improve from 0.00070
# Epoch 137/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 9.3065e-05 - val_loss: 7.4220e-04
#
# Epoch 00137: val_loss did not improve from 0.00070
# Epoch 138/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 9.3786e-05 - val_loss: 7.8259e-04
#
# Epoch 00138: val_loss did not improve from 0.00070
# Epoch 139/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 9.2254e-05 - val_loss: 7.2167e-04
#
# Epoch 00139: val_loss did not improve from 0.00070
# Epoch 140/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 8.6864e-05 - val_loss: 7.1683e-04
#
# Epoch 00140: val_loss did not improve from 0.00070
# Epoch 141/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 9.0813e-05 - val_loss: 7.6813e-04
#
# Epoch 00141: val_loss did not improve from 0.00070
# Epoch 142/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 9.1738e-05 - val_loss: 7.2078e-04
#
# Epoch 00142: val_loss did not improve from 0.00070
# Epoch 143/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 8.8198e-05 - val_loss: 7.7216e-04
#
# Epoch 00143: val_loss did not improve from 0.00070
# Epoch 144/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 9.0123e-05 - val_loss: 7.5759e-04
#
# Epoch 00144: val_loss did not improve from 0.00070
# Epoch 145/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 8.9784e-05 - val_loss: 7.3655e-04
#
# Epoch 00145: val_loss did not improve from 0.00070
# Epoch 146/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 9.0883e-05 - val_loss: 7.3606e-04
#
# Epoch 00146: val_loss did not improve from 0.00070
# Epoch 147/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 9.6109e-05 - val_loss: 7.2274e-04
#
# Epoch 00147: val_loss did not improve from 0.00070
# Epoch 148/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 8.9454e-05 - val_loss: 7.6469e-04
#
# Epoch 00148: val_loss did not improve from 0.00070
# Epoch 149/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 8.8763e-05 - val_loss: 7.6798e-04
#
# Epoch 00149: val_loss did not improve from 0.00070
# Epoch 150/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 8.7266e-05 - val_loss: 7.1539e-04
#
# Epoch 00150: val_loss did not improve from 0.00070

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = 'test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    # 顯示圖片
    plt.imshow(img, cmap='gray')
    
    # 畫上關鍵點
    for i in range(0, 30, 2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15, 15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
# 實現圖片以及關機點 label 做左右翻轉的函數
def augment_data(img, points):
    rows, cols = img.shape
    new_img = np.copy(img)
    
    # 翻轉圖片
    for i in range(96):
        for j in range(48):
            temp = img[i][j]
            new_img[i][j] = img[i][cols-j-1]
            new_img[i][cols-j-1] = temp
            
    # 翻轉關鍵點 label
    new_points = np.copy(points)
    for i in range(0, 30, 2):
        new_points[i] = -points[i]
    
    # 調整對稱的 label
    new_points_temp = np.copy(new_points)
    new_points[0:2] = new_points_temp[2:4]
    new_points[2:4] = new_points_temp[0:2]
    new_points[4:6] = new_points_temp[8:10]
    new_points[6:8] = new_points_temp[10:12]
    new_points[8:10] = new_points_temp[4:6]
    new_points[10:12] = new_points_temp[6:8]
    new_points[12:14] = new_points_temp[16:18]
    new_points[14:16] = new_points_temp[18:20]
    new_points[16:18] = new_points_temp[12:14]
    new_points[18:20] = new_points_temp[14:16]
    new_points[22:24] = new_points_temp[24:26]
    new_points[24:26] = new_points_temp[22:24]
        
    return new_img, new_points

# %%
flip_img, flip_points = augment_data(imgs_train[0], points_train[0])
fig = plt.figure()

ax = fig.add_subplot(1, 2, 1, xticks=[], yticks=[])
plot_keypoints(imgs_train[0], points_train[0]) # 原來的圖片

ax = fig.add_subplot(1, 2, 2, xticks=[], yticks=[])
plot_keypoints(flip_img, flip_points) # 翻轉後的圖片

# %%
# 創建 list
aug_imgs_train = []
aug_points_train = []

# 對所有原始資料做 augmentation
for i in range(imgs_train.shape[0]):
    # 做左右翻轉
    aug_img, aug_point = augment_data(imgs_train[i], points_train[i])
    
    # append 原始資料
    aug_imgs_train.append(imgs_train[i])
    aug_points_train.append(points_train[i]) 
    
    # append 做過 augmentation 後的資料
    aug_imgs_train.append(aug_img)
    aug_points_train.append(aug_point) 

# convert to numpy
aug_imgs_train = np.array(aug_imgs_train)   
aug_points_train = np.copy(aug_points_train)

print(aug_imgs_train.shape)
print(aug_points_train.shape)
# Out:
# (4280, 96, 96)
# (4280, 30)

# %%
# model checkpoint 
checkpoint_aug = ModelCheckpoint('best_weights_augment.h5', verbose=1, save_best_only=True)
# training the model
hist_model_aug = model_with_augment.fit(aug_imgs_train.reshape(aug_imgs_train.shape[0], 96, 96, 1), aug_points_train, 
                                        validation_split=0.2, batch_size=64, callbacks=[checkpoint_aug, hist], 
                                        shuffle=True, epochs=150, verbose=1)
# Out:
# Train on 3424 samples, validate on 856 samples
# Epoch 1/150
# 3424/3424 [==============================] - 8s 2ms/step - loss: 0.0037 - val_loss: 0.0019
#
# Epoch 00001: val_loss improved from inf to 0.00188, saving model to best_weights_augment.h5
# Epoch 2/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 0.0012 - val_loss: 0.0019
#
# Epoch 00002: val_loss improved from 0.00188 to 0.00185, saving model to best_weights_augment.h5
# Epoch 3/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 0.0010 - val_loss: 0.0018
#
# Epoch 00003: val_loss improved from 0.00185 to 0.00176, saving model to best_weights_augment.h5
# Epoch 4/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 8.4252e-04 - val_loss: 0.0016
#
# Epoch 00004: val_loss improved from 0.00176 to 0.00162, saving model to best_weights_augment.h5
# Epoch 5/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 6.9570e-04 - val_loss: 0.0013
#
# Epoch 00005: val_loss improved from 0.00162 to 0.00126, saving model to best_weights_augment.h5
# Epoch 6/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 5.6135e-04 - val_loss: 0.0011
#
# Epoch 00006: val_loss improved from 0.00126 to 0.00108, saving model to best_weights_augment.h5
# Epoch 7/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 4.9175e-04 - val_loss: 9.7013e-04
#
# Epoch 00007: val_loss improved from 0.00108 to 0.00097, saving model to best_weights_augment.h5
# Epoch 8/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 4.4494e-04 - val_loss: 9.1484e-04
#
# Epoch 00008: val_loss improved from 0.00097 to 0.00091, saving model to best_weights_augment.h5
# Epoch 9/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 4.1576e-04 - val_loss: 9.2250e-04
#
# Epoch 00009: val_loss did not improve from 0.00091
# Epoch 10/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 3.8979e-04 - val_loss: 8.7266e-04
#
# Epoch 00010: val_loss improved from 0.00091 to 0.00087, saving model to best_weights_augment.h5
# Epoch 11/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 3.6084e-04 - val_loss: 8.1219e-04
#
# Epoch 00011: val_loss improved from 0.00087 to 0.00081, saving model to best_weights_augment.h5
# Epoch 12/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 3.4072e-04 - val_loss: 7.8460e-04
#
# Epoch 00012: val_loss improved from 0.00081 to 0.00078, saving model to best_weights_augment.h5
# Epoch 13/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 3.2429e-04 - val_loss: 7.7671e-04
#
# Epoch 00013: val_loss improved from 0.00078 to 0.00078, saving model to best_weights_augment.h5
# Epoch 14/150
# 3424/3424 [==============================] - 8s 2ms/step - loss: 3.0814e-04 - val_loss: 7.9021e-04
#
# Epoch 00014: val_loss did not improve from 0.00078
# Epoch 15/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 2.9792e-04 - val_loss: 7.2542e-04
#
# Epoch 00015: val_loss improved from 0.00078 to 0.00073, saving model to best_weights_augment.h5
# Epoch 16/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 2.8235e-04 - val_loss: 7.5388e-04
#
# Epoch 00016: val_loss did not improve from 0.00073
# Epoch 17/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 2.7861e-04 - val_loss: 7.6037e-04
#
# Epoch 00017: val_loss did not improve from 0.00073
# Epoch 18/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 2.7238e-04 - val_loss: 7.2940e-04
#
# Epoch 00018: val_loss did not improve from 0.00073
# Epoch 19/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 2.5773e-04 - val_loss: 7.3906e-04
#
# Epoch 00019: val_loss did not improve from 0.00073
# Epoch 20/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 2.4507e-04 - val_loss: 6.8657e-04
#
# Epoch 00020: val_loss improved from 0.00073 to 0.00069, saving model to best_weights_augment.h5
# Epoch 21/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 2.4566e-04 - val_loss: 7.0962e-04
#
# Epoch 00021: val_loss did not improve from 0.00069
# Epoch 22/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 2.3122e-04 - val_loss: 7.0186e-04
#
# Epoch 00022: val_loss did not improve from 0.00069
# Epoch 23/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 2.2572e-04 - val_loss: 6.6252e-04
#
# Epoch 00023: val_loss improved from 0.00069 to 0.00066, saving model to best_weights_augment.h5
# Epoch 24/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 2.2130e-04 - val_loss: 6.7125e-04
#
# Epoch 00024: val_loss did not improve from 0.00066
# Epoch 25/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 2.1614e-04 - val_loss: 7.3051e-04
#
# Epoch 00025: val_loss did not improve from 0.00066
# Epoch 26/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 2.1386e-04 - val_loss: 7.1332e-04
#
# Epoch 00026: val_loss did not improve from 0.00066
# Epoch 27/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 2.0529e-04 - val_loss: 6.8351e-04
#
# Epoch 00027: val_loss did not improve from 0.00066
# Epoch 28/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 2.0129e-04 - val_loss: 6.7182e-04
#
# Epoch 00028: val_loss did not improve from 0.00066
# Epoch 29/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.9406e-04 - val_loss: 6.7323e-04
#
# Epoch 00029: val_loss did not improve from 0.00066
# Epoch 30/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.9457e-04 - val_loss: 6.7042e-04
#
# Epoch 00030: val_loss did not improve from 0.00066
# Epoch 31/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.8752e-04 - val_loss: 7.1638e-04
#
# Epoch 00031: val_loss did not improve from 0.00066
# Epoch 32/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.8640e-04 - val_loss: 6.6322e-04
#
# Epoch 00032: val_loss did not improve from 0.00066
# Epoch 33/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.8025e-04 - val_loss: 6.7811e-04
#
# Epoch 00033: val_loss did not improve from 0.00066
# Epoch 34/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.8140e-04 - val_loss: 6.4947e-04
#
# Epoch 00034: val_loss improved from 0.00066 to 0.00065, saving model to best_weights_augment.h5
# Epoch 35/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.7200e-04 - val_loss: 6.5178e-04
#
# Epoch 00035: val_loss did not improve from 0.00065
# Epoch 36/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.7257e-04 - val_loss: 6.5395e-04
#
# Epoch 00036: val_loss did not improve from 0.00065
# Epoch 37/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.6847e-04 - val_loss: 6.7023e-04
#
# Epoch 00037: val_loss did not improve from 0.00065
# Epoch 38/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.6521e-04 - val_loss: 6.5681e-04
#
# Epoch 00038: val_loss did not improve from 0.00065
# Epoch 39/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.6487e-04 - val_loss: 6.4532e-04
#
# Epoch 00039: val_loss improved from 0.00065 to 0.00065, saving model to best_weights_augment.h5
# Epoch 40/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.6479e-04 - val_loss: 6.7636e-04
#
# Epoch 00040: val_loss did not improve from 0.00065
# Epoch 41/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.5822e-04 - val_loss: 6.4559e-04
#
# Epoch 00041: val_loss did not improve from 0.00065
# Epoch 42/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.5666e-04 - val_loss: 6.8364e-04
#
# Epoch 00042: val_loss did not improve from 0.00065
# Epoch 43/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.5976e-04 - val_loss: 6.4267e-04
#
# Epoch 00043: val_loss improved from 0.00065 to 0.00064, saving model to best_weights_augment.h5
# Epoch 44/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.5298e-04 - val_loss: 6.6421e-04
#
# Epoch 00044: val_loss did not improve from 0.00064
# Epoch 45/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.4988e-04 - val_loss: 6.5680e-04
#
# Epoch 00045: val_loss did not improve from 0.00064
# Epoch 46/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.4927e-04 - val_loss: 6.3004e-04
#
# Epoch 00046: val_loss improved from 0.00064 to 0.00063, saving model to best_weights_augment.h5
# Epoch 47/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.4497e-04 - val_loss: 6.4771e-04
#
# Epoch 00047: val_loss did not improve from 0.00063
# Epoch 48/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.4509e-04 - val_loss: 6.4404e-04
#
# Epoch 00048: val_loss did not improve from 0.00063
# Epoch 49/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.4343e-04 - val_loss: 6.5339e-04
#
# Epoch 00049: val_loss did not improve from 0.00063
# Epoch 50/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.3765e-04 - val_loss: 6.4311e-04
#
# Epoch 00050: val_loss did not improve from 0.00063
# Epoch 51/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.4228e-04 - val_loss: 6.7633e-04
#
# Epoch 00051: val_loss did not improve from 0.00063
# Epoch 52/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.3593e-04 - val_loss: 6.4863e-04
#
# Epoch 00052: val_loss did not improve from 0.00063
# Epoch 53/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.3275e-04 - val_loss: 6.3834e-04
#
# Epoch 00053: val_loss did not improve from 0.00063
# Epoch 54/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.3445e-04 - val_loss: 6.5761e-04
#
# Epoch 00054: val_loss did not improve from 0.00063
# Epoch 55/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.3110e-04 - val_loss: 6.7249e-04
#
# Epoch 00055: val_loss did not improve from 0.00063
# Epoch 56/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.2982e-04 - val_loss: 6.3040e-04
#
# Epoch 00056: val_loss did not improve from 0.00063
# Epoch 57/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.3035e-04 - val_loss: 6.8945e-04
#
# Epoch 00057: val_loss did not improve from 0.00063
# Epoch 58/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.2844e-04 - val_loss: 6.7175e-04
#
# Epoch 00058: val_loss did not improve from 0.00063
# Epoch 59/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.3041e-04 - val_loss: 6.6782e-04
#
# Epoch 00059: val_loss did not improve from 0.00063
# Epoch 60/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.2394e-04 - val_loss: 6.4626e-04
#
# Epoch 00060: val_loss did not improve from 0.00063
# Epoch 61/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.2555e-04 - val_loss: 6.3475e-04
#
# Epoch 00061: val_loss did not improve from 0.00063
# Epoch 62/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.2319e-04 - val_loss: 6.6304e-04
#
# Epoch 00062: val_loss did not improve from 0.00063
# Epoch 63/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.2193e-04 - val_loss: 6.7374e-04
#
# Epoch 00063: val_loss did not improve from 0.00063
# Epoch 64/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.1864e-04 - val_loss: 6.5404e-04
#
# Epoch 00064: val_loss did not improve from 0.00063
# Epoch 65/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.2134e-04 - val_loss: 6.7564e-04
#
# Epoch 00065: val_loss did not improve from 0.00063
# Epoch 66/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.1681e-04 - val_loss: 6.4729e-04
#
# Epoch 00066: val_loss did not improve from 0.00063
# Epoch 67/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.1601e-04 - val_loss: 6.4085e-04
#
# Epoch 00067: val_loss did not improve from 0.00063
# Epoch 68/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.1343e-04 - val_loss: 6.6219e-04
#
# Epoch 00068: val_loss did not improve from 0.00063
# Epoch 69/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.1364e-04 - val_loss: 6.0985e-04
#
# Epoch 00069: val_loss improved from 0.00063 to 0.00061, saving model to best_weights_augment.h5
# Epoch 70/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.1453e-04 - val_loss: 6.3888e-04
#
# Epoch 00070: val_loss did not improve from 0.00061
# Epoch 71/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.0969e-04 - val_loss: 6.5600e-04
#
# Epoch 00071: val_loss did not improve from 0.00061
# Epoch 72/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.1070e-04 - val_loss: 6.1753e-04
#
# Epoch 00072: val_loss did not improve from 0.00061
# Epoch 73/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.1036e-04 - val_loss: 6.4821e-04
#
# Epoch 00073: val_loss did not improve from 0.00061
# Epoch 74/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.0920e-04 - val_loss: 6.7570e-04
#
# Epoch 00074: val_loss did not improve from 0.00061
# Epoch 75/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.1118e-04 - val_loss: 6.6557e-04
#
# Epoch 00075: val_loss did not improve from 0.00061
# Epoch 76/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.0588e-04 - val_loss: 6.2137e-04
#
# Epoch 00076: val_loss did not improve from 0.00061
# Epoch 77/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.0719e-04 - val_loss: 6.2862e-04
#
# Epoch 00077: val_loss did not improve from 0.00061
# Epoch 78/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.0339e-04 - val_loss: 6.3462e-04
#
# Epoch 00078: val_loss did not improve from 0.00061
# Epoch 79/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.0689e-04 - val_loss: 6.3717e-04
#
# Epoch 00079: val_loss did not improve from 0.00061
# Epoch 80/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.0520e-04 - val_loss: 6.2291e-04
#
# Epoch 00080: val_loss did not improve from 0.00061
# Epoch 81/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.0140e-04 - val_loss: 6.3498e-04
#
# Epoch 00081: val_loss did not improve from 0.00061
# Epoch 82/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.0434e-04 - val_loss: 6.5599e-04
#
# Epoch 00082: val_loss did not improve from 0.00061
# Epoch 83/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 9.8078e-05 - val_loss: 6.4456e-04
#
# Epoch 00083: val_loss did not improve from 0.00061
# Epoch 84/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.0168e-04 - val_loss: 6.4337e-04
#
# Epoch 00084: val_loss did not improve from 0.00061
# Epoch 85/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.0028e-04 - val_loss: 6.2561e-04
#
# Epoch 00085: val_loss did not improve from 0.00061
# Epoch 86/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 9.8508e-05 - val_loss: 6.3330e-04
#
# Epoch 00086: val_loss did not improve from 0.00061
# Epoch 87/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 1.0006e-04 - val_loss: 6.3944e-04
#
# Epoch 00087: val_loss did not improve from 0.00061
# Epoch 88/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 9.7496e-05 - val_loss: 6.3269e-04
#
# Epoch 00088: val_loss did not improve from 0.00061
# Epoch 89/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 9.7019e-05 - val_loss: 6.2081e-04
#
# Epoch 00089: val_loss did not improve from 0.00061
# Epoch 90/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 9.7226e-05 - val_loss: 6.7556e-04
#
# Epoch 00090: val_loss did not improve from 0.00061
# Epoch 91/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 9.9494e-05 - val_loss: 6.1973e-04
#
# Epoch 00091: val_loss did not improve from 0.00061
# Epoch 92/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 9.6273e-05 - val_loss: 6.4995e-04
#
# Epoch 00092: val_loss did not improve from 0.00061
# Epoch 93/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 9.4683e-05 - val_loss: 6.3768e-04
#
# Epoch 00093: val_loss did not improve from 0.00061
# Epoch 94/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 9.7379e-05 - val_loss: 6.3628e-04
#
# Epoch 00094: val_loss did not improve from 0.00061
# Epoch 95/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 9.4807e-05 - val_loss: 6.2687e-04
#
# Epoch 00095: val_loss did not improve from 0.00061
# Epoch 96/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 9.5058e-05 - val_loss: 6.5668e-04
#
# Epoch 00096: val_loss did not improve from 0.00061
# Epoch 97/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 9.3718e-05 - val_loss: 6.2497e-04
#
# Epoch 00097: val_loss did not improve from 0.00061
# Epoch 98/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 9.2992e-05 - val_loss: 6.2250e-04
#
# Epoch 00098: val_loss did not improve from 0.00061
# Epoch 99/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 9.3453e-05 - val_loss: 6.4294e-04
#
# Epoch 00099: val_loss did not improve from 0.00061
# Epoch 100/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 9.4480e-05 - val_loss: 6.4178e-04
#
# Epoch 00100: val_loss did not improve from 0.00061
# Epoch 101/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 9.1646e-05 - val_loss: 6.2909e-04
#
# Epoch 00101: val_loss did not improve from 0.00061
# Epoch 102/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 8.9964e-05 - val_loss: 6.5865e-04
#
# Epoch 00102: val_loss did not improve from 0.00061
# Epoch 103/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 9.1665e-05 - val_loss: 6.5000e-04
#
# Epoch 00103: val_loss did not improve from 0.00061
# Epoch 104/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 9.3743e-05 - val_loss: 6.3230e-04
#
# Epoch 00104: val_loss did not improve from 0.00061
# Epoch 105/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 9.0879e-05 - val_loss: 6.3024e-04
#
# Epoch 00105: val_loss did not improve from 0.00061
# Epoch 106/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 9.1333e-05 - val_loss: 6.3096e-04
#
# Epoch 00106: val_loss did not improve from 0.00061
# Epoch 107/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 9.1555e-05 - val_loss: 6.3871e-04
#
# Epoch 00107: val_loss did not improve from 0.00061
# Epoch 108/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 9.1008e-05 - val_loss: 6.3983e-04
#
# Epoch 00108: val_loss did not improve from 0.00061
# Epoch 109/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 8.9757e-05 - val_loss: 6.3362e-04
#
# Epoch 00109: val_loss did not improve from 0.00061
# Epoch 110/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 8.8609e-05 - val_loss: 6.3088e-04
#
# Epoch 00110: val_loss did not improve from 0.00061
# Epoch 111/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 8.9204e-05 - val_loss: 6.1814e-04
#
# Epoch 00111: val_loss did not improve from 0.00061
# Epoch 112/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 8.8490e-05 - val_loss: 6.4282e-04
#
# Epoch 00112: val_loss did not improve from 0.00061
# Epoch 113/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 8.8285e-05 - val_loss: 6.1744e-04
#
# Epoch 00113: val_loss did not improve from 0.00061
# Epoch 114/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 8.8738e-05 - val_loss: 6.4882e-04
#
# Epoch 00114: val_loss did not improve from 0.00061
# Epoch 115/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 8.5529e-05 - val_loss: 6.3239e-04
#
# Epoch 00115: val_loss did not improve from 0.00061
# Epoch 116/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 9.0129e-05 - val_loss: 6.3146e-04
#
# Epoch 00116: val_loss did not improve from 0.00061
# Epoch 117/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 8.7482e-05 - val_loss: 6.4270e-04
#
# Epoch 00117: val_loss did not improve from 0.00061
# Epoch 118/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 8.4494e-05 - val_loss: 6.5681e-04
#
# Epoch 00118: val_loss did not improve from 0.00061
# Epoch 119/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 8.7006e-05 - val_loss: 6.4983e-04
#
# Epoch 00119: val_loss did not improve from 0.00061
# Epoch 120/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 8.5425e-05 - val_loss: 6.2442e-04
#
# Epoch 00120: val_loss did not improve from 0.00061
# Epoch 121/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 8.6417e-05 - val_loss: 6.3254e-04
#
# Epoch 00121: val_loss did not improve from 0.00061
# Epoch 122/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 8.5447e-05 - val_loss: 6.6111e-04
#
# Epoch 00122: val_loss did not improve from 0.00061
# Epoch 123/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 8.6608e-05 - val_loss: 6.3490e-04
#
# Epoch 00123: val_loss did not improve from 0.00061
# Epoch 124/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 8.3517e-05 - val_loss: 6.2050e-04
#
# Epoch 00124: val_loss did not improve from 0.00061
# Epoch 125/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 8.4191e-05 - val_loss: 6.6052e-04
#
# Epoch 00125: val_loss did not improve from 0.00061
# Epoch 126/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 8.2128e-05 - val_loss: 6.3050e-04
#
# Epoch 00126: val_loss did not improve from 0.00061
# Epoch 127/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 8.3732e-05 - val_loss: 6.5737e-04
#
# Epoch 00127: val_loss did not improve from 0.00061
# Epoch 128/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 8.2186e-05 - val_loss: 6.3413e-04
#
# Epoch 00128: val_loss did not improve from 0.00061
# Epoch 129/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 8.1724e-05 - val_loss: 6.5045e-04
#
# Epoch 00129: val_loss did not improve from 0.00061
# Epoch 130/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 8.1127e-05 - val_loss: 6.6828e-04
#
# Epoch 00130: val_loss did not improve from 0.00061
# Epoch 131/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 8.2592e-05 - val_loss: 6.4057e-04
#
# Epoch 00131: val_loss did not improve from 0.00061
# Epoch 132/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 8.3333e-05 - val_loss: 6.4656e-04
#
# Epoch 00132: val_loss did not improve from 0.00061
# Epoch 133/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 8.3191e-05 - val_loss: 6.3713e-04
#
# Epoch 00133: val_loss did not improve from 0.00061
# Epoch 134/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 8.2288e-05 - val_loss: 6.5463e-04
#
# Epoch 00134: val_loss did not improve from 0.00061
# Epoch 135/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 8.1282e-05 - val_loss: 6.1830e-04
#
# Epoch 00135: val_loss did not improve from 0.00061
# Epoch 136/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 8.1492e-05 - val_loss: 6.2779e-04
#
# Epoch 00136: val_loss did not improve from 0.00061
# Epoch 137/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 8.0752e-05 - val_loss: 6.2144e-04
#
# Epoch 00137: val_loss did not improve from 0.00061
# Epoch 138/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 8.0734e-05 - val_loss: 6.3349e-04
#
# Epoch 00138: val_loss did not improve from 0.00061
# Epoch 139/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 8.0552e-05 - val_loss: 6.3384e-04
#
# Epoch 00139: val_loss did not improve from 0.00061
# Epoch 140/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 7.9250e-05 - val_loss: 6.4776e-04
#
# Epoch 00140: val_loss did not improve from 0.00061
# Epoch 141/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 8.1300e-05 - val_loss: 6.3822e-04
#
# Epoch 00141: val_loss did not improve from 0.00061
# Epoch 142/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 7.9479e-05 - val_loss: 6.4285e-04
#
# Epoch 00142: val_loss did not improve from 0.00061
# Epoch 143/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 7.8880e-05 - val_loss: 6.5128e-04
#
# Epoch 00143: val_loss did not improve from 0.00061
# Epoch 144/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 7.9847e-05 - val_loss: 6.5790e-04
#
# Epoch 00144: val_loss did not improve from 0.00061
# Epoch 145/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 7.9718e-05 - val_loss: 6.5520e-04
#
# Epoch 00145: val_loss did not improve from 0.00061
# Epoch 146/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 7.7554e-05 - val_loss: 6.2387e-04
#
# Epoch 00146: val_loss did not improve from 0.00061
# Epoch 147/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 7.7809e-05 - val_loss: 6.5011e-04
#
# Epoch 00147: val_loss did not improve from 0.00061
# Epoch 148/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 7.6742e-05 - val_loss: 6.3127e-04
#
# Epoch 00148: val_loss did not improve from 0.00061
# Epoch 149/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 7.9827e-05 - val_loss: 6.4135e-04
#
# Epoch 00149: val_loss did not improve from 0.00061
# Epoch 150/150
# 3424/3424 [==============================] - 7s 2ms/step - loss: 7.9271e-05 - val_loss: 6.2909e-04
#
# Epoch 00150: val_loss did not improve from 0.00061

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model_aug.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model_aug.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# 增加了左右翻轉以後，應該可以在這個範例中看到 loss 有稍微降一點（可能因為隨機而略有不同），這裡的目的主要還是去體會對原始圖像做 augmentation 以後，也要對原始 label 做合理的調整。
